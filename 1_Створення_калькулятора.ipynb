# %% [markdown]
# # Створення калькулятора

# %% [markdown]
# 1. Запустіть на виконання наступну комірку з кодом. Введіть потрібні дані й перегляньте результат

# %%
first_number = int(input('Введіть перше число: ')) ;
second_number = int(input('Введіть друге число: ')) ;
print("Сума чисел: ", first_number + second_number)
# Out:
# Введіть перше число: 12
# Введіть друге число: 23
# Сума чисел:  35

# %% [markdown]
# 2. В наступній пустій комірці спробуйте переписати код так, щоб виводились **сума, різниця, добуток та частка** введених чисел:

# %%
first_number = int(input('Введіть перше число: ')) ;
second_number = int(input('Введіть друге число: ')) ;
print("Сума чисел: ", first_number + second_number)
print("Різниця чисел:", first_number - second_number)
print("Добуток чисел:", first_number * second_number)
print("Частка чисел:", first_number / second_number)
# Out:
# Введіть перше число: 4
# Введіть друге число: 2
# Сума чисел:  6
# Різниця чисел: 2
# Добуток чисел: 8
# Частка чисел: 2.0

# %% [markdown]
# 3. А тепер давайте порахуємо відстань між Києвом та Полтавою у милях (1 миля = 1,60934 км), знаючи що в кілометрах це 305,3 км. Підказка: для заокруглення до першого знаку після коми використовуйте конструкцію
# ``` python
# round(x, 1)
# ```
# Результат обчислень збережіть у змінній ```distMiles```

# %%
distMiles = round(305.3 / 1.60934, 1)
print(distMiles)
# Out:
# 189.7

# %% [markdown]
# ### Перевіримо чи все гаразд:
# До речі - це гарний приклад використання [Wolfram Alpha](https://www.wolframalpha.com/)!

# %%
# !pip install wolframalpha
app_id = '2ARWPW-8GAHYH5HQH'

from wolframalpha import Client

client = Client(app_id)
res = client.query('distance between Poltava and Kiev') # in km or miles

# якби результат складався б з кількох блоків даних
#for pod in res.pods:
#  for sub in pod.subpods:
#    print(sub.plaintext)

res = next(res.results).text
# print(res)

correct = float(res.split(' ')[0])
if distMiles==correct:
  print('Все правильно! Ви молодець!')
else:
  print(f"Щось не те - має вийти {correct} миль, а у Вас вийшло {distMiles}!")
# Out:
# Collecting wolframalpha
#   Downloading wolframalpha-5.1.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting xmltodict (from wolframalpha)
#   Downloading xmltodict-1.0.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from wolframalpha) (10.8.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from wolframalpha) (6.0.1)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from wolframalpha) (0.28.1)
# Requirement already satisfied: multidict in /usr/local/lib/python3.12/dist-packages (from wolframalpha) (6.7.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->wolframalpha) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->wolframalpha) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->wolframalpha) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->wolframalpha) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->wolframalpha) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx->wolframalpha) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx->wolframalpha) (4.15.0)
# Downloading wolframalpha-5.1.3-py3-none-any.whl (6.3 kB)
# Downloading xmltodict-1.0.2-py3-none-any.whl (13 kB)
# Installing collected packages: xmltodict, wolframalpha
# Successfully installed wolframalpha-5.1.3 xmltodict-1.0.2
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2064576347.py in <cell line: 0>()
#       5
#       6 client = Client(app_id)
# ----> 7 res = client.query('distance between Poltava and Kiev') # in km or miles
#       8
#       9 # якби результат складався б з кількох блоків даних
#
# /usr/local/lib/python3.12/dist-packages/wolframalpha/__init__.py in query(self, input, params, **kwargs)
#     117         https://products.wolframalpha.com/api/documentation.html#6
#     118         """
# --> 119         return asyncio.run(self.aquery(input, params, **kwargs))
#     120
#     121     async def aquery(self, input, params=(), **kwargs):
#
# /usr/lib/python3.12/asyncio/runners.py in run(main, debug, loop_factory)
#     189     if events._get_running_loop() is not None:
#     190         # fail fast with short traceback
# --> 191         raise RuntimeError(
#     192             "asyncio.run() cannot be called from a running event loop")
#     193
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %% [markdown]
# Нагадую, що цю вправу ви також можете виконати на [Microsoft Learn](https://docs.microsoft.com/ru-ru/learn/modules/intro-to-python/7-exercise-input).

# %% [markdown]
# ### Результат виконання роботи:

# %%
distMiles = round(305.3 / 1.60934, 1)
print(distMiles)
# Out:
# 189.7
